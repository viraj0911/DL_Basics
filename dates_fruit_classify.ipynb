# %%
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
df = pd.read_excel('Date_Fruit_Datasets.xlsx')
df.head()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0    0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1    0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2    0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3    0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4    0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
#
#    KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  \
# 0      4.2287 -59191263232 -50714214400 -39922372608     58.7255     54.9554
# 1      3.1704 -34233065472 -37462601728 -31477794816     50.0259     52.8168
# 2      4.7192 -93948354560 -74738221056 -60311207936     65.4772     59.2860
# 3      8.2618 -32074307584 -32060925952 -29575010304     43.3900     44.1259
# 4      4.4146 -39980974080 -35980042240 -25593278464     52.7743     50.9080
#
#    ALLdaub4RB  Class
# 0     47.8400  BERHI
# 1     47.8315  BERHI
# 2     51.9378  BERHI
# 3     41.1882  BERHI
# 4     42.6666  BERHI
#
# [5 rows x 35 columns]

# %%
le = LabelEncoder()
df["Class"] = le.fit_transform(df["Class"])
df
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    422163  2378.9080    837.8484    645.6693        0.6373  733.1539
# 1    338136  2085.1440    723.8198    595.2073        0.5690  656.1464
# 2    526843  2647.3940    940.7379    715.3638        0.6494  819.0222
# 3    416063  2351.2100    827.9804    645.2988        0.6266  727.8378
# 4    347562  2160.3540    763.9877    582.8359        0.6465  665.2291
# ..      ...        ...         ...         ...           ...       ...
# 893  255403  1925.3650    691.8453    477.1796        0.7241  570.2536
# 894  365924  2664.8230    855.4633    551.5447        0.7644  682.5752
# 895  254330  1926.7360    747.4943    435.6219        0.8126  569.0545
# 896  238955  1906.2679    716.6485    441.8297        0.7873  551.5859
# 897  343792  2289.2720    823.8438    534.7757        0.7607  661.6113
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0      0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1      0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2      0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3      0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4      0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
# ..        ...          ...     ...           ...  ...         ...         ...
# 893    0.9785       261028  0.7269        1.4499  ...      2.2423      2.3704
# 894    0.9466       386566  0.6695        1.5510  ...      3.4109      3.5805
# 895    0.9925       256255  0.7240        1.7159  ...      2.2759      2.5090
# 896    0.9604       248795  0.6954        1.6220  ...      2.6769      2.6874
# 897    0.9781       351472  0.6941        1.5405  ...      2.5138      3.0369
#
#      KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  \
# 0        4.2287 -59191263232 -50714214400 -39922372608     58.7255
# 1        3.1704 -34233065472 -37462601728 -31477794816     50.0259
# 2        4.7192 -93948354560 -74738221056 -60311207936     65.4772
# 3        8.2618 -32074307584 -32060925952 -29575010304     43.3900
# 4        4.4146 -39980974080 -35980042240 -25593278464     52.7743
# ..          ...          ...          ...          ...         ...
# 893      2.7202 -25296416768 -19168882688 -18473392128     49.0869
# 894      3.9910 -31605219328 -21945366528 -19277905920     46.8086
# 895      2.6951 -22242772992 -19594921984 -17592152064     44.1325
# 896      2.7991 -26048595968 -21299822592 -19809978368     51.2267
# 897      3.0865 -31983476736 -20482514944 -21219354624     47.3454
#
#      ALLdaub4RG  ALLdaub4RB  Class
# 0       54.9554     47.8400      0
# 1       52.8168     47.8315      0
# 2       59.2860     51.9378      0
# 3       44.1259     41.1882      0
# 4       50.9080     42.6666      0
# ..          ...         ...    ...
# 893     43.0422     42.4153      6
# 894     39.1046     36.5502      6
# 895     40.7986     40.9769      6
# 896     45.7162     45.6260      6
# 897     38.6966     39.6738      6
#
# [898 rows x 35 columns]

# %%
X = df.loc[:, df.columns != 'Class'].to_numpy()
y = df["Class"].to_numpy()

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[0.77227446, 0.77207865, 0.56560444, ..., 0.67351302, 0.55053709,
#         0.4946647 ],
#        [0.61783464, 0.61747978, 0.43690403, ..., 0.53892305, 0.51634149,
#         0.49450116],
#        [0.96467405, 0.9133745 , 0.6817325 , ..., 0.77796738, 0.61978216,
#         0.57350706],
#        ...,
#        [0.46380101, 0.53411457, 0.46362467, ..., 0.44774729, 0.32417389,
#         0.36261751],
#        [0.43554209, 0.52334284, 0.42881001, ..., 0.55750041, 0.40280492,
#         0.45206697],
#        [0.62823025, 0.72490601, 0.5497979 , ..., 0.4974535 , 0.29056351,
#         0.33754565]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
class ANN_Classify(nn.Module):
    def __init__(self):
        super().__init__()
        self.stack = nn.Sequential(
            nn.Linear(34,68),
            nn.ReLU(),
            nn.Linear(68,120),
            nn.ReLU(),
            nn.Linear(120,90),
            nn.ReLU(),
            nn.Linear(90,30),
            nn.ReLU(),
            nn.Linear(30,7),
        )

    def forward(self,x):
        x = self.stack(x)
        x = torch.softmax(x, dim = -1)
        return x

# %%
model = ANN_Classify()
print(model)
# Out:
# ANN_Classify(
#   (stack): Sequential(
#     (0): Linear(in_features=34, out_features=68, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=68, out_features=120, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=120, out_features=90, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=90, out_features=30, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=30, out_features=7, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
inputs = torch.tensor(X_train, dtype=torch.float32)
labels = torch.tensor(y_train, dtype=torch.float32)

epochs = 2000
for epoch in range(epochs):
    outputs = model(inputs)
    loss = criterion(outputs,labels.long())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [100/2000], Loss: 1.5256
# Epoch [200/2000], Loss: 1.5249
# Epoch [300/2000], Loss: 1.5244
# Epoch [400/2000], Loss: 1.5232
# Epoch [500/2000], Loss: 1.5218
# Epoch [600/2000], Loss: 1.5208
# Epoch [700/2000], Loss: 1.5203
# Epoch [800/2000], Loss: 1.5199
# Epoch [900/2000], Loss: 1.5196
# Epoch [1000/2000], Loss: 1.5192
# Epoch [1100/2000], Loss: 1.5187
# Epoch [1200/2000], Loss: 1.5182
# Epoch [1300/2000], Loss: 1.5173
# Epoch [1400/2000], Loss: 1.5165
# Epoch [1500/2000], Loss: 1.3844
# Epoch [1600/2000], Loss: 1.3663
# Epoch [1700/2000], Loss: 1.3614
# Epoch [1800/2000], Loss: 1.3589
# Epoch [1900/2000], Loss: 1.3571
# Epoch [2000/2000], Loss: 1.3564

# %%
def softmax_accuracy(probs, labels):
    """
    Calculate the accuracy of predictions given softmax probabilities and true labels.

    Parameters:
    probs (torch.Tensor): A tensor of shape (batch_size, num_classes) with softmax probabilities.
    labels (torch.Tensor): A tensor of shape (batch_size,) with true labels.

    Returns:
    float: The accuracy of the predictions.
    """
    # Convert softmax probabilities to predicted class labels
    _, predicted_labels = torch.max(probs, 1)
    
    # Compare predicted labels to true labels
    correct_predictions = (predicted_labels == labels).sum().item()
    
    # Calculate accuracy
    accuracy = correct_predictions / labels.size(0)
   
    return accuracy

# %%
softmax_accuracy(model(torch.from_numpy(X_test).float()), torch.from_numpy(y_test).long())
# Out:
# 0.7388888888888889
